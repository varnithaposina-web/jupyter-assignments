# %%
username = "admin"
password = "1234"
if username == "admin" and password == "1234":
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Login Successful

# %%
marks = [45, 78, 90, 33, 60]

pass_count = 0
fail_count = 0

for m in marks:
    if m >= 50:
        pass_count +=1
    else:
        fail_count +=1

print(f"Total Passed: {pass_count}")
print(f"Total Failed: {fail_count}")
# Out:
# Total Passed: 3
# Total Failed: 2

# %%
names = [" Alice ", "bob", " CHARLIE "]
cleaned_names = [n.strip().lower() for n in names]

print("Cleaned List:", cleaned_names)
# Out:
# Cleaned List: ['alice', 'bob', 'charlie']

# %%
messages = ["Hi", "Welcome to the platform", "OK"]

for msg in messages:
    length = len(msg)
    status = ""

    if length > 10:
        status = " - [FLAGGED: Too Long]"

    print(f"Message: '{msg}' | Length: {length}{status}")
# Out:
# Message: 'Hi' | Length: 2
# Message: 'Welcome to the platform' | Length: 23 - [FLAGGED: Too Long]
# Message: 'OK' | Length: 2

# %%
logs = ["INFO", "ERROR", "WARNING", "ERROR"]

error_count = logs.count("ERROR")

print(f"Number of ERROR entries detected: {error_count}")
# Out:
# Number of ERROR entries detected: 2
